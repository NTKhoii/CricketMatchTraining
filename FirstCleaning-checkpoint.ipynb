# %%
https://www.espncricinfo.com/records/highest-career-batting-average-282910

# %%
import pandas as pd

# %%
df = pd.read_csv('Downloads/CricketTestMatchData.csv',delimiter=';')

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 2     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 3     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# 4   H Sutcliffe (ENG)  1924-1935   54    84   9  4555   194  60.73  6558+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 60   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 61  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 62  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 63    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 64   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0   58.60   29  13   7  626+   6
# ...

# %%
df.rename(columns={'NO':'Not_Outs','HS':'highest_inns_score','BF':'balls_faced','SR':'batting_strike_rate','4s':'boundary_fours','6s':'boundary_sixes'},inplace=True)

# %%
#check NULL value
df.isnull().any()
# Out:
# Player                 False
# Span                   False
# Mat                    False
# Inns                   False
# Not_Outs               False
# Runs                   False
# highest_inns_score     False
# Ave                    False
# balls_faced             True
# batting_strike_rate    False
# 100                    False
# 50                     False
# 0                      False
# boundary_fours         False
# boundary_sixes         False
# dtype: bool

# %%
filt=(df['balls_faced'].isna()==True)
df.loc[filt]
# Out:
#              Player  Mat  Inns  Not_Outs  Runs  highest_inns_score    Ave  \
# 7        ED Weekes    48    81         5  4455                 207  58.61
# 13      CL Walcott    44    74         7  3798                 220  56.68
# 56  Hon.FS Jackson    20    33         4  1415                 144  48.79
#
#    balls_faced  batting_strike_rate  100  50  0 boundary_fours boundary_sixes  \
# 7          NaN                  0.0   15  19  6           258+              2
# 13         NaN                  0.0   15  14  1           107+             11
# 56         NaN                  0.0    5   6  3            51+              0
#
#     Rookie_Year  Final_Year Country
# 7          1948        1958      WI
# 13         1948        1960      WI
# 56         1893        1905     ENG

# %%
df['balls_faced']=df['balls_faced'].fillna(0)

# %%
df[df['Player']=='CL Walcott (WI)']
# Out:
# Empty DataFrame
# Columns: [Player, Mat, Inns, Not_Outs, Runs, highest_inns_score, Ave, balls_faced, batting_strike_rate, 100, 50, 0, boundary_fours, boundary_sixes, Rookie_Year, Final_Year, Country]
# Index: []

# %%
#drop duplicates

# %%
df.duplicated().head(50)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14     True
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33     True
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# dtype: bool

# %%
filt1=df['Player'].duplicated()==1
df.loc[filt1]
# Out:
#               Player       Span  Mat  Inns  Not_Outs   Runs  \
# 14   CL Walcott (WI)  1948-1960   44    74         7   3798
# 33  BC Lara (ICC/WI)  1990-2006  131   232         6  11953
#
#    highest_inns_score    Ave balls_faced  batting_strike_rate  100  50   0  \
# 14                220  56.68           0                 0.00   15  14   1
# 33               400*  52.88       19753                60.51   34  48  17
#
#    boundary_fours boundary_sixes
# 14           107+             11
# 33           1559             88

# %%
duplicate_name=['CL Walcott (WI)','BC Lara (ICC/WI)']
df[df['Player'].isin(duplicate_name)]
# Out:
#               Player       Span  Mat  Inns  Not_Outs   Runs  \
# 13   CL Walcott (WI)  1948-1960   44    74         7   3798
# 14   CL Walcott (WI)  1948-1960   44    74         7   3798
# 26  BC Lara (ICC/WI)  1990-2006  131   232         6  11953
# 33  BC Lara (ICC/WI)  1990-2006  131   232         6  11953
#
#    highest_inns_score    Ave balls_faced  batting_strike_rate  100  50   0  \
# 13                220  56.68           0                 0.00   15  14   1
# 14                220  56.68           0                 0.00   15  14   1
# 26               400*  52.88       19753                60.51   34  48  17
# 33               400*  52.88       19753                60.51   34  48  17
#
#    boundary_fours boundary_sixes
# 13           107+             11
# 14           107+             11
# 26           1559             88
# 33           1559             88

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#                Player       Span  Mat  Inns  Not_Outs  Runs  \
# 0    DG Bradman (AUS)  1928-1948   52    80        10  6996
# 1      AC Voges (AUS)  2015-2016   20    31         7  1485
# 2     RG Pollock (SA)  1963-1970   23    41         4  2256
# 3     GA Headley (WI)  1930-1954   22    40         4  2190
# 4   H Sutcliffe (ENG)  1924-1935   54    84         9  4555
# ..                ...        ...  ...   ...       ...   ...
# 60   KD Walters (AUS)  1965-1981   74   125        14  5357
# 61  GC Smith (ICC/SA)  2002-2014  117   205        13  9265
# 62  WH Ponsford (AUS)  1924-1934   29    48         4  2122
# 63    SJ McCabe (AUS)  1930-1938   39    62         5  2748
# 64   DR Jardine (ENG)  1928-1934   22    33         6  1296
#
#    highest_inns_score    Ave balls_faced  batting_strike_rate  100  50   0  \
# 0                 334  99.94       9800+                58.60   29  13   7
# 1                269*  61.87        2667                55.68    5   4   2
# ...

# %%
duplicate_name=['CL Walcott (WI)','BC Lara (ICC/WI)']
df[df['Player'].isin(duplicate_name)]
# Out:
#               Player       Span  Mat  Inns  Not_Outs   Runs  \
# 13   CL Walcott (WI)  1948-1960   44    74         7   3798
# 26  BC Lara (ICC/WI)  1990-2006  131   232         6  11953
#
#    highest_inns_score    Ave balls_faced  batting_strike_rate  100  50   0  \
# 13                220  56.68           0                 0.00   15  14   1
# 26               400*  52.88       19753                60.51   34  48  17
#
#    boundary_fours boundary_sixes
# 13           107+             11
# 26           1559             88

# %%
#split up Span into Start and End Date
df['Span'].str.split(pat='-')
# Out:
# 0     [1928, 1948]
# 1     [2015, 2016]
# 2     [1963, 1970]
# 3     [1930, 1954]
# 4     [1924, 1935]
#           ...
# 60    [1965, 1981]
# 61    [2002, 2014]
# 62    [1924, 1934]
# 63    [1930, 1938]
# 64    [1928, 1934]
# Name: Span, Length: 63, dtype: object

# %%
df['Rookie_Year']=df['Span'].str.split(pat='-').str[0]
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_14880\1740907504.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Rookie_Year']=df['Span'].str.split(pat='-').str[0]

# %%
df['Final_Year']=df['Span'].str.split(pat='-').str[1]
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_14880\1405677318.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Final_Year']=df['Span'].str.split(pat='-').str[1]

# %%
df
# Out:
#                Player       Span  Mat  Inns  Not_Outs  Runs  \
# 0    DG Bradman (AUS)  1928-1948   52    80        10  6996
# 1      AC Voges (AUS)  2015-2016   20    31         7  1485
# 2     RG Pollock (SA)  1963-1970   23    41         4  2256
# 3     GA Headley (WI)  1930-1954   22    40         4  2190
# 4   H Sutcliffe (ENG)  1924-1935   54    84         9  4555
# ..                ...        ...  ...   ...       ...   ...
# 60   KD Walters (AUS)  1965-1981   74   125        14  5357
# 61  GC Smith (ICC/SA)  2002-2014  117   205        13  9265
# 62  WH Ponsford (AUS)  1924-1934   29    48         4  2122
# 63    SJ McCabe (AUS)  1930-1938   39    62         5  2748
# 64   DR Jardine (ENG)  1928-1934   22    33         6  1296
#
#    highest_inns_score    Ave balls_faced  batting_strike_rate  100  50   0  \
# 0                 334  99.94       9800+                58.60   29  13   7
# 1                269*  61.87        2667                55.68    5   4   2
# ...

# %%
df=df.drop(columns='Span')

# %%
df
# Out:
#                Player  Mat  Inns  Not_Outs  Runs highest_inns_score    Ave  \
# 0    DG Bradman (AUS)   52    80        10  6996                334  99.94
# 1      AC Voges (AUS)   20    31         7  1485               269*  61.87
# 2     RG Pollock (SA)   23    41         4  2256                274  60.97
# 3     GA Headley (WI)   22    40         4  2190               270*  60.83
# 4   H Sutcliffe (ENG)   54    84         9  4555                194  60.73
# ..                ...  ...   ...       ...   ...                ...    ...
# 60   KD Walters (AUS)   74   125        14  5357                250  48.26
# 61  GC Smith (ICC/SA)  117   205        13  9265                277  48.25
# 62  WH Ponsford (AUS)   29    48         4  2122                266  48.22
# 63    SJ McCabe (AUS)   39    62         5  2748                232  48.21
# 64   DR Jardine (ENG)   22    33         6  1296                127  48.00
#
#    balls_faced  batting_strike_rate  100  50   0 boundary_fours  \
# ...

# %%
#split the country out of the name
df['Player'].str.split(pat=['()'])
df['Name']=df['Player'].str.split(pat='(').str[0]
df['Country']=df['Player'].str.split(pat='(').str[1]

# %%
df
# Out:
#                Player  Mat  Inns  Not_Outs  Runs highest_inns_score    Ave  \
# 0    DG Bradman (AUS)   52    80        10  6996                334  99.94
# 1      AC Voges (AUS)   20    31         7  1485               269*  61.87
# 2     RG Pollock (SA)   23    41         4  2256                274  60.97
# 3     GA Headley (WI)   22    40         4  2190               270*  60.83
# 4   H Sutcliffe (ENG)   54    84         9  4555                194  60.73
# ..                ...  ...   ...       ...   ...                ...    ...
# 60   KD Walters (AUS)   74   125        14  5357                250  48.26
# 61  GC Smith (ICC/SA)  117   205        13  9265                277  48.25
# 62  WH Ponsford (AUS)   29    48         4  2122                266  48.22
# 63    SJ McCabe (AUS)   39    62         5  2748                232  48.21
# 64   DR Jardine (ENG)   22    33         6  1296                127  48.00
#
#    balls_faced  batting_strike_rate  100  50   0 boundary_fours  \
# ...

# %%
df['Country'].str.split(')')
df['Country']=df['Country'].str.split(')').str[0]

# %%
df
# Out:
#           Player  Mat  Inns  Not_Outs  Runs highest_inns_score    Ave  \
# 0    DG Bradman    52    80        10  6996                334  99.94
# 1      AC Voges    20    31         7  1485               269*  61.87
# 2    RG Pollock    23    41         4  2256                274  60.97
# 3    GA Headley    22    40         4  2190               270*  60.83
# 4   H Sutcliffe    54    84         9  4555                194  60.73
# ..           ...  ...   ...       ...   ...                ...    ...
# 60   KD Walters    74   125        14  5357                250  48.26
# 61     GC Smith   117   205        13  9265                277  48.25
# 62  WH Ponsford    29    48         4  2122                266  48.22
# 63    SJ McCabe    39    62         5  2748                232  48.21
# 64   DR Jardine    22    33         6  1296                127  48.00
#
#    balls_faced  batting_strike_rate  100  50   0 boundary_fours  \
# ...

# %%
df.dtypes
# Out:
# Player                  object
# Mat                     object
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# highest_inns_score      object
# Ave                    float64
# balls_faced             object
# batting_strike_rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# boundary_fours          object
# boundary_sixes          object
# Rookie_Year             object
# Final_Year              object
# Country                 object
# dtype: object

# %%
df['highest_inns_score']=df['highest_inns_score'].str.split(pat='*').str[0]

# %%
df['highest_inns_score']=df['highest_inns_score'].astype('int')

# %%
#change the type of Rookie_Year and Final_Year to int
df[['Rookie_Year','Final_Year']]=df[['Rookie_Year','Final_Year']].astype('int')

# %%
df['Mat']=df['Mat'].str.split('*').str[0]
df['Mat']=df['Mat'].astype('int')

# %%
df.dtypes
# Out:
# Player                  object
# Mat                      int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# highest_inns_score       int64
# Ave                    float64
# balls_faced             object
# batting_strike_rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# boundary_fours          object
# boundary_sixes          object
# Rookie_Year              int64
# Final_Year               int64
# Country                 object
# dtype: object

# %%
df['balls_faced']=df['balls_faced'].str.split('+').str[0]

# %%
df['balls_faced']=df['balls_faced'].fillna(0)

# %%
df['balls_faced']=df['balls_faced'].astype('int')

# %%
df.dtypes
# Out:
# Player                  object
# Mat                      int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# highest_inns_score       int64
# Ave                    float64
# balls_faced              int64
# batting_strike_rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# boundary_fours          object
# boundary_sixes          object
# Rookie_Year              int64
# Final_Year               int64
# Country                 object
# dtype: object

# %%
## Build career_length columns
df['Career_length']=df['Final_Year']-df['Rookie_Year']

# %%
df
# Out:
#                Player  Mat  Inns  Not_Outs   Runs  highest_inns_score    Ave  \
# 0         DG Bradman    52    80        10   6996                 334  99.94
# 1           AC Voges    20    31         7   1485                 269  61.87
# 2         RG Pollock    23    41         4   2256                 274  60.97
# 3         GA Headley    22    40         4   2190                 270  60.83
# 4        H Sutcliffe    54    84         9   4555                 194  60.73
# 5          E Paynter    20    31         5   1540                 243  59.23
# 6      KF Barrington    82   131        15   6806                 256  58.67
# 7          ED Weekes    48    81         5   4455                 207  58.61
# 8         WR Hammond    85   140        16   7249                 336  58.45
# 9          GS Sobers    93   160        21   8032                 365  57.78
# 10     KC Sangakkara   134   233        17  12400                 319  57.40
# ...

# %%
## Calculation with the dataframe

# %%
#Ques1: Cricketers in this DF what is the Average career length
df['Career_length'].mean()
# Out:
# np.float64(13.031746031746032)

# %%
#Ques2: AVG Batting_Strike_Rate for cricketers who played over 10 years
df[df['Career_length']>10]['batting_strike_rate'].mean()
# Out:
# np.float64(47.9565909090909)

# %%
#Ques3: find the number of cricketers who played before 1960
df[df['Rookie_Year']<1960]['Player'].count()
# Out:
# np.int64(23)

# %%
#Ques4: Max height Inns Score by country
df.groupby('Country')['highest_inns_score'].max().to_frame('HighInCountry').reset_index().sort_values('HighInCountry')
# Out:
#     Country  HighInCountry
# 12      ZIM            232
# 7        NZ            251
# 6       IND            254
# 4    ICC/SA            277
# 9        SA            278
# 8       PAK            313
# 2   ICC/IND            319
# 3   ICC/PAK            329
# 1       ENG            364
# 11       WI            365
# 10       SL            374
# 0       AUS            380
# 5    ICC/WI            400

# %%
#Ques5: Hundreds, fifties, ducks (0) AVG by country

# %%
df.groupby('Country')[['100','50','0']].mean()
# Out:
#                100         50          0
# Country
# AUS      20.625000  28.375000   8.562500
# ENG      12.692308  21.230769   4.307692
# ICC/IND  29.500000  47.500000  12.000000
# ICC/PAK  25.000000  46.000000  15.000000
# ICC/SA   36.000000  48.000000  13.500000
# ICC/WI   34.000000  48.000000  17.000000
# IND      29.500000  36.500000  10.750000
# NZ       18.500000  23.000000   6.000000
# PAK      17.600000  23.600000   7.800000
# SA        9.800000  20.200000   3.400000
# SL       28.666667  44.000000  12.333333
# WI       16.625000  25.625000   7.250000
# ZIM      12.000000  27.000000   5.000000
